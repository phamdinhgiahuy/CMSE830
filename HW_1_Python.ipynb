# %% [markdown]
# ____
# # <font color=#FFBB00> HW #1: Data Science and (a little) Python </font>
# ____
#
# This HW is due at midnight Friday in D2L. Remember that HWs are not done in groups, but _on your own_. However, if you need help, you are free to use the internet, other students in the class or the instructors.
#
# If you have general questions or interesting insights/tricks, please post them on Slack.

# %% [markdown]
# ____
#
# ### Markdown
#
# This HW uses a lot of markdown. Knowing markdown well will make your Jupyter notebook life a lot more fun. And, you can use markdown for many other tasks that have nothing to do with Jupyter notebooks - it's a general way to format text. For example, when I want to do quick editing tasks, I very often use [a markdown editor like this one](https://macdown.uranusjr.com/). (If you use a Windows OS, there are equivalents that you can find in the link below.)
#
# Before you get started on the HW problems below, read these webpages:
# * [Markdown Guide](https://www.markdownguide.org/getting-started/)
# * [Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# 👨🏽‍🏫 You will notice that I am using several features of markdown to write this cell! If you open this markdown cell, you can see all of the commands I used.
#
# As you answer the questions below, use the features of markdown, such as lists, web links and [tables](https://www.tablesgenerator.com/markdown_tables).
#
# 👩🏽‍💻 Once you are done learning markdown well, continue to the HW below. **Important:** problem 11 is much more involved than the others, so you might start with that.
# ____

# %% [markdown]
# ✍🏼 **Problem 1**: Read the syllabus for this class and answer the following two questions. Open a markdown cell below this one to put your answers.
# 1. What is the late policy for this class?
# 2. Describe in your own words the Spartan Code of Honor.

# %% [markdown]
# 📝 **Answer to Problem 1**
# 1. The in-class assignments are done in small groups, so they are turned in with your group at the end of the class, before you leave. In some (hopefully very rare) cases, if there is a problem that emerges during an in-class project, an extra slot of time to complete the project outside of class, up to a few hours. You, and your entire group, will receive zero credit for any project turned in after that time. (If you do not show up for the in-class project, you will receive a zero for that assignment.) If homework is late it will be graded as normal and a 0.75 factor will be applied to that grade to yield the final, late grade. All homework submitted after one week of its due date receives a grade of zero. Finally, the assignments associated with your project throughout the semester are graded in the same way as homework, with the exception of the poster, which obviously cannot be done late
# 2. As a Michigan State University student, I swear by honesty, integrity and highest ethical standard in all but not only limited to my academic practices at Michigan State university. I will never compromise honor and personal integrity for grades and will encourage my peers to do the same.

# %% [markdown]
# ✍🏼 **Problem 2**: Define these terms in your own words, again in a new markdown cell. Discuss how they might be used differently in a data science context.
# * cardinal number
# * ordinal number
# * nominal number

# %% [markdown]
# 📝 **Answer to Problem 2**
# * cardinal number: is the count by which we can get a quantitative grasp of the thing it represents. It is a numeric value that we can do calculation on.
# * ordinal number: there is an inherent order or ranking for this type of number, it represents a clear organization of categories showing which comes first and which comes next.
# * nominal number: is like a name or a lable we give to an object, the purpose is just to classify or distinguish between them, there is no order or ranking of any sort.
#
#     👉 Depending on the interest and the inherent nature of a data science problems we can choose how to record, categorize and represent our data in a meaningful way while making sure that we do not take on unnecessary computational resource. For example if we just want to distinguish 3 different type of apples, there no need to assign a cardinal or ordinal number for each type to indicate the rank or the interval, but if we want to seperate these apple into different sizes (small, medium, large) then we have to assign ordinal numbers to them.

# %% [markdown]
# ✍🏼 **Problem 3**: Write a paragraph about John W. Tukey. You can use the class sides, but also Wikipedia or any other source. Why is he important to data science? Open a markdown cell below this one to put your discussion.

# %% [markdown]
# 📝 **Answer to Problem 3**
#
# John Wilder Tukey was the pioneer who laid several key foundations of the Data Science as widely known today. His concept of Exploratory Data Analysis (EDA) revolutionized data science, it emphasizes the importance of visualizing and understanding data to explore and gain insights from them, which in turn reveals meaningful patterns and outliers. In many ways, EDA was a precursor to Data Science so it is fair to consider John Wilder Tukey the father of modern Data Science. Tukey has soon realized and harnessed the power of computer science especially computer graphics to make studying multivariate data much easier. He was also the creator of many statistical methods and procedures that are widely used in data analysis, including the Fast Fourier Transform (FFT) algorithm, which is a key concept in signal processing and data compression. His legacy is a long lasting one and the path that he trod has led to unimaginable branches and applications of modern day Data Science.

# %% [markdown]
# ✍🏼 **Problem 4**: Open a markdown cell and give your definition of data science.

# %% [markdown]
# 📝 **Answer to Problem 4**
#
# Data Science is using the combined understanding in mathematics, computational science and scientific knowledge of a specific field to derive meaningful implication, uncover hidden secrets and stories or event predict the future from all the generated information. Based on which, complicated problems can be solved, tough decisions are easier to be made and processes are optimized.

# %% [markdown]
# ✍🏼 **Problem 5**: In a markdown cell below, write two sentences that use the term 'data' as:
# 1. a plural noun,
# 2. a mass noun.

# %% [markdown]
# 📝 **Answer to Problem 5**
# 1.  * The recorded cellphones sales data last month show a significant drop in demand.
#     * We have to identify the outliers in our recent equipment data to see what has gone wrong.
# 2.  * The ability to work with data has become increasingly relevant these days
#     * There is no data to support his ridiculous claim.

# %% [markdown]
# ✍🏼 **Problem 6**: Describe in your own words, in a new markdown cell, what a tuple, a list and an array are in Python. Why do we need all three of these? How are they similar? How are they different? What are the use cases for each?

# %% [markdown]
# 📝 **Answer to Problem 6**
#
# * a tuple is a container of flexible types of elements, these elements maintain the order they are created with. A tuple is denoted by the enclosing `()`
# * a list is a container of flexible types of elements, these elements maintain the order they are created with. A list is denoted by the enclosing `[]`
# * a array is a typical data structure in the `NumPy` library. It can only store one type of data at a time.
# * the key differences and similarities between these three are:
#     * tuple and list both contain flexible typing, ordered elements but tuple is immutable while list is mutable, in other words, tuple is like an unchangable list and list is a flexible, easy to modify data container.
#     * The key difference of array from tuple and list is that all the elements in an array have to be of the same type while list and tuple simutaneously accept any type of data as their elements.
# * We need all three of these because each specific problems may call for the usage of one of these three. Each of these three has their own advantage and disavantage, for example while list and tuple are tolerent towards data types they are much less efficient in terms of computation compared to array, especially on large datasets. Or the ability to be modify with ease for list can be both its strength and shortcoming, it makes list versatile but less reliable than tuple so in cases where we need our data to be fixed and unchangeable we should use tuple, for like a dictionary key.

# %% [markdown]
# ✍🏼 **Problem 7**: In a code cell, write code that creates a tuple of values. Print the contents. Then convert that tuple to a list, and print the list. Finally, convert the list to an array and print that. Give two cases where this procedure works and does not work.

# %% [markdown]
# 👉 Case where this procedure works:

# %%
mytuple = ('hi', 'hello', 'how are you')
print('tuple: ', mytuple)
mylist = list(mytuple)
print('list: ', mylist)

import numpy as np
myarray = np.array(mylist)
print('array: ', myarray)
# Out:
# tuple:  ('hi', 'hello', 'how are you')
# list:  ['hi', 'hello', 'how are you']
# array:  ['hi' 'hello' 'how are you']

# %% [markdown]
# 👉 Case where this procedure does not work:

# %%
mytuple = (2, [3], 'hello', 5.5, False)
print('tuple: ', mytuple)

mylist = list(mytuple)
print('list: ', mylist)

import numpy as np
myarray = np.array(mylist)
print('array: ', myarray)
# Out:
# tuple:  (2, [3], 'hello', 5.5, False)
# list:  [2, [3], 'hello', 5.5, False]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 8
#       5 print('list: ', mylist)
#       7 import numpy as np
# ----> 8 myarray = np.array(mylist)
#       9 print('array: ', myarray)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.

# %% [markdown]
# ✍🏼 **Problem 8**: A classic dataset you should be aware of is the "mpg" dataset, which stands for "miles per gallon". In a code cell below, input the mpg dataset, show a portion of the data, print statistics for each column and make a Seaborn pairplot using "origin" as the hue.

# %%
import seaborn as sns

df_mpg = sns.load_dataset("mpg")
print(df_mpg.head())
print(df_mpg.describe())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
sns.pairplot(df_mpg, hue="origin")

# %%
sns.pairplot(df_mpg, hue="model_year")

# %% [markdown]
# ✍🏼 **Problem 9**: Open a markdown cell below and discuss what you learned from the mpg dataset. Vary the pairplot to explore the data in different ways. Do you learn anything from the basic IDA process? Does the EDA process provide additional information? At the end of your general discussion, be sure to include:
# * What do you get from the data? That is, what did you learn that you did not already know?
# * Even if the data itself is not that interesting in itself, what uses might this dataset have as practice for doing data science?

# %% [markdown]
# 📝 **Answer to Problem 9**
#
# From the basic IDA process, I just get the general information regarding what the data look like: the attributes, the type of data for each attributes, how many there are, the basic statistics summary for each numeric columns but not the comparison between different categories like "origin" or "modemodel_year".
#
# The EDA process definitely helps in getting a more meaningful interpretation for comparisons and trends. It seems that USA has the largest number of recorded model name so the spread for these data is also wider than Japan and Europe. But in terms of mpg efficiency, Japan models seem to lead, these are the part of the datasets that I did not already know. For model years, it is obvious that the newer the model year, the less bulky a model is and the more powerful and more effiecient it becomes. We can use this dataset analysis to for example decide on the most engery efficient compact engine models and compare that with sales data to see whether customers are energy-conscious or they just buy a car base on the design.

# %% [markdown]
# ✍🏼 **Problem 10**: Perhaps the most popular dataset of all time is the "iris" dataset. This is a dataset you should know in great detail, as it appears everywhere. Repeat the previous problem, but now for the "iris" dataset.

# %%
import seaborn as sns

df_iris = sns.load_dataset("iris")
print(df_iris.head())
print(df_iris.describe())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(df_iris, hue="species")

# %% [markdown]
# 📝 **Answer to Problem 10**
#
# From the basic IDA process, I get the general information regarding what the data look like: the attributes, the type of data for each attributes, how many there are, the basic statistics summary for each numeric columns this dataset is a bit easier to see since there are only species of flowers and the other attributes are the recorded dimension of their flowers.
#
# The EDA process helps in getting a more meaningful interpretation for comparisons and trends. It seems that setosa has the smallest petal size followed by versicolor and then virginica. For sepal dimension, the data spread out more, setosa sepals are generally wide but short while the other two have thinner but longer sepal.

# %% [markdown]
# ✍🏼 **Problem 11**: This problem is the most difficult: be sure to give yourself plenty of time to work on it.
#
# If you get stuck, put your questions in the general channel on Slack so that other students can help and learn from you.
#
# There are two goals of this problem:
# 1. develop your ability to manage new Python libraries on your computer,
# 2. begin the first steps of building a DS-based web app for your midterm project.
#
# The reason this will be challenging is that:
# * you have some choices to make that will be unique to you,
# * your computer, its operating system and your library distributions are not necessarily like other students'.
#
# Here are the steps  to follow:
# 1. If you don't have one already, put a text editor on your computer. There are many to choose from: [Sublime](https://www.sublimetext.com/), [VSCode](https://code.visualstudio.com/), and so on. There are many times when using a Jupyter notebook, as amazing as they are, won't work. If you haven't used any of these editors, I recommend getting a few so that you can compare them. The choice is often very personal, which is why I am giving you the opportunity to explore and choose the best one for you.
# 2. Be sure that you can work at the command line. How this works differs greatly from computer to computer. For example, on a Mac you always use the [Terminal](https://en.wikipedia.org/wiki/Terminal_(macOS)). As with the editors, there are many choices, [like this](https://iterm2.com/).  If you are a windows user, you definitely want to [read this](https://www.makeuseof.com/tag/a-beginners-guide-to-the-windows-command-line/). Together, the editor and the command line will allow you to execute `.py` files, which can be really useful if you are using another computer (such as a cluster located somewhere else, such as MSU's HPCC facility).
# 3. Once those two steps are done, open the editor you chose and put this code in it, giving it any name you want, but ending with `.py`:
# ```
# import streamlit as st
# import seaborn as sns
# import pandas as pd
# from sklearn.datasets import load_wine
# import altair as alt
# wine_data = load_wine()
# labels = wine_data.feature_names
# targets = wine_data.target
# print(labels)
# df_form = pd.DataFrame(wine_data.data, columns = labels)
# df_form['targets'] = targets
# st.write("""
# # Italian Wine Dataset
# How are malic acid and alcohol correlated in Italian wines?
# """)
# alt_handle = alt.Chart(df_form).mark_circle(size=60).encode(x='alcohol', y='malic_acid',
# 	color='hue', tooltip=['ash', 'magnesium',
# 	'proanthocyanins']).interactive()
# st.altair_chart(alt_handle)
# ```
# Note that you will likely have to install some libraries on your computer.
# 4. At the command line, run your file using `streamlit run name.py`, where `name` is whatever name you chose for your file in your editor. An interactive web app should appear in your browser. Don't worry about the details at this point, which we will cover later in the course: the goal for this HW is just to **get your computer setup properly** for deployable interactive DS apps.
# 5. In a markdown cell, put the answers to these questions:
# * which editor(s) did you choose, and why?
# * what did you decide to use for your command line? (e.g., are you on OSX and using the built-in `Terminal`?)
# * did you have any problems installing the libraries, such as `streamlit` and `altair`?
# * yes or no, did you get the interactive app working? if not, give details of your situation (i.e., your computer, what you tried, what you saw), so that we can fix the problems for next time.
#
# Again, if you have issues, post your questions. Everyone has a different background in setting up their computer and every computer is different.
#
# Once you have it working: congrats on your first, tiny data science app!

# %% [markdown]
# 📝 **Answer to Problem 11**
# * which editor(s) did you choose, and why?
#
#     👉 I use `VSCode` as I have it already installed on my Laptop and the UI is friendly, straighfoward with all of the feature I need so far (syntax autocompletion, syntax hightlight, extensions installation) it can even run Jupyter notebook file alongside with the directory explorer tab and a terminal/output/variable tracker at the bottom which is extremely convenient
# * what did you decide to use for your command line? (e.g., are you on OSX and using the built-in `Terminal`?)
#
#     👉 I'm on `Window` and I'm using the default built-in `Command Prompt` for my command line
# * did you have any problems installing the libraries, such as `streamlit` and `altair`?
#
#     👉 as first I tried to install using `conda install streamlit` and it failed, the terminal returns there's packages conflict.
#     ```Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
#     Solving environment: \
#     Found conflicts! Looking for incompatible packages.
#     This can take several minutes.  Press CTRL-C to abort.
#     failed```
#     I then tried `pip install streamlit` and it worked
#
# * yes or no, did you get the interactive app working? if not, give details of your situation (i.e., your computer, what you tried, what you saw), so that we can fix the problems for next time.
#
#     👉 Yes, it worked. I saw the interactive graph of **Italian Wine Dataset** where I can hover the mouse over a data point to see the values of its atrributes, zoom in/out, ...
