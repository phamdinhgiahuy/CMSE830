# %% [markdown]
# ### When you answer your questions, please use [emoji](https://getemoji.com/) and [good markdown](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html) so that it is easy for Mahyar to find your work and grade it. Thanks!

# %% [markdown]
# Be sure to put your name here:
# *  **Pham Dinh Gia Huy**

# %% [markdown]
# ____
#
# # HW #3
#
# ____

# %% [markdown]
# ____
# ## GitHub
#
# It is important to have a public place to show your work, and GitHub (GH) is one of the standards you need to know for this. By the end of the semester you will have GH repos (repositories) for both of your projects. Among other goals, this will allow you to show off your work!
#
# I expect that the students in this class have very different experiences with GH, so this problem might be really short or really long.
#
# ✍🏻 (5pts) First, make a GH account for yourself [here](https://github.com/). Put your GH account information in a markdown cell. If you already have a GH repo, you do not need to create a new one; just put the name in the markdown cell. Or, create a new account for this class. I would like to collect the projects in one place so that we can all see them, even after the class is over.
#
# If you want to brush up on GH, or learn it from scratch, I recommend watching some YouTube videos. I recommend [this one](https://www.youtube.com/watch?v=x0EYpi38Yp4), or [this one](https://www.youtube.com/watch?v=DVRQoVRzMIY) and this pair: [first one](https://www.youtube.com/watch?v=USjZcfj8yxE) and [second one](https://www.youtube.com/watch?v=nhNq2kIvi9s).
#
# If you have any questions, please ask us! We are here to help!
#
# ✍🏻 (2 pts) Second, once you have your personal GH repo setup, practice by putting your web apps from this class there.
#
# Put a link to your web app here so that Mahyar can check to see that it worked.

# %% [markdown]
# 👉 GH account: [Gia Huy GitHub😎](https://github.com/phamdinhgiahuy)
#
# 👉 GH repo with CMSE previous Web app HW: [CMSE HW2 Webapp](https://github.com/phamdinhgiahuy/CMSE830/blob/master/HW2_updated.py) https://cmse830-hw3.streamlit.app/

# %% [markdown]
# ____
# ## Project Practice
#
# This week you are going to practice for your midterm project. The midterm project is DS and the final project is machine learning (ML). What we want to explore in this problem is what we can do with DS.
#
# You will choose the topic of your project. This means:
# * you can use a dataset that you have from your job,
# * you can use a dataset that leads to a publication,
# * or, you can use a standard dataset if you don't have your own.
#
# The point is that this is flexible and can scale with each student. What I don't recommend is building your own dataset. While I would very much love to see that, there is a risk that it will take too long and possibly not lead to anything. (If you really want to do that, contact me!)
#
# Because the projects will be quite different, the instructions will be somewhat vague on purpose. But, here are the rules:
# 1. use most of the tools of EDA,
# 2. use visualization at a professional level (which we will cover soon),
# 3. be as quantitive as possible, using statistical tools,
# 4. have a question or goal in mind -- **a story**; or, if you explore a dataset, you should reach a new conclusion or observation about the dataset,
# 5. the final result will be a web app that others can access. (I will walk you through using `streamlit` with `GitHub` and `Heroku`, but talk to me if you want to use any of the many other options.)
#
# ✍🏻 (15 pts) Pick **three** datasets - your choice. You can find a lot of datasets [here](https://archive.ics.uci.edu/); search for topics that are of most interest to you. From these three datasets, write code to perform EDA on them and put that below. Below the EDA code cells for each dataset, open a markdown cell and write a paragraph that answers these questions:
# 1. why did you pick this dataset?
# 2. are there any interesting insights you gained from performing EDA on this dataset? (use all/most of the Seaborn tools we discussed this week)
# 3. are there any actionable insights you can get from this data? (For example, if you were a CEO and looking at the mpg dataset, what might you conclude?)
#
# Finally, open a new markdown and discuss which of these three datasets would make the best project dataset. Were some of the datasets disappointing? Was one of the datasets much richer with possibilities? The reason you are asked to pick three is that some datasets is that you need to be able to assess which datasets are more or less interesting for your projects.
#
# [Here is an example you can follow that uses a wine dataset.](https://murillogroupmsu.com/wine/) It is also [at GH](https://gist.github.com/MurilloGroupMSU/678f61bbe225bdd166e8b946765d2931).

# %% [markdown]
# ### 👉 Dataset 1: Spotify Song Attributes Dataset

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

spotify_df = pd.read_csv(r"C:\Users\Admin\OneDrive - Michigan State University\Courses\CMSE 830\HW and Assignment\Dataset\Spotify_Song_Attributes.csv")
spotify_df = spotify_df.sort_values("msPlayed", ascending=False)
spotify_df_top1000 = spotify_df[:1000]

# %% [markdown]
# 🎸 There are 10000 records in this dataset but I just want to examine the top 1000 songs based on the total ms that it is played (`"msPlayed"` column)

# %%
spotify_df_top1000.head()
# Out:
#                  trackName    artistName   msPlayed                  genre  \
# 4194  Sparkle - movie ver.      RADWIMPS  158367130                  j-pop
# 9234  Sparkle - movie ver.      RADWIMPS  158367130                  j-pop
# 1001                   色香水  Yoh kamiyama  109652914      japanese teen pop
# 6041                   色香水  Yoh kamiyama  109652914      japanese teen pop
# 7098                  Gone    Blake Rose  105798353  australian electropop
#
#       danceability  energy   key  loudness  mode  speechiness  ...  liveness  \
# 4194         0.372   0.426  11.0    -8.421   1.0       0.0339  ...     0.109
# 9234         0.372   0.426  11.0    -8.421   1.0       0.0339  ...     0.109
# 1001         0.613   0.857   7.0    -5.272   1.0       0.0271  ...     0.256
# 6041         0.613   0.857   7.0    -5.272   1.0       0.0271  ...     0.256
# 7098         0.317   0.545  11.0    -6.439   0.0       0.0468  ...     0.116
#
#       valence    tempo            type                      id  \
# 4194    0.287  123.993  audio_features  3A4FRzgve9BjfKbvVXRIFO
# 9234    0.287  123.993  audio_features  3A4FRzgve9BjfKbvVXRIFO
# 1001    0.698  147.974  audio_features  7FpABRyv5TaZz0llkhjPgc
# 6041    0.698  147.974  audio_features  7FpABRyv5TaZz0llkhjPgc
# 7098    0.140  139.014  audio_features  2dPT9UxyHm71quNyj3C4YE
#
#                                        uri  \
# 4194  spotify:track:3A4FRzgve9BjfKbvVXRIFO
# 9234  spotify:track:3A4FRzgve9BjfKbvVXRIFO
# 1001  spotify:track:7FpABRyv5TaZz0llkhjPgc
# 6041  spotify:track:7FpABRyv5TaZz0llkhjPgc
# 7098  spotify:track:2dPT9UxyHm71quNyj3C4YE
#
#                                              track_href  \
# 4194  https://api.spotify.com/v1/tracks/3A4FRzgve9Bj...
# 9234  https://api.spotify.com/v1/tracks/3A4FRzgve9Bj...
# 1001  https://api.spotify.com/v1/tracks/7FpABRyv5TaZ...
# 6041  https://api.spotify.com/v1/tracks/7FpABRyv5TaZ...
# 7098  https://api.spotify.com/v1/tracks/2dPT9UxyHm71...
#
#                                            analysis_url duration_ms  \
# 4194  https://api.spotify.com/v1/audio-analysis/3A4F...    537653.0
# 9234  https://api.spotify.com/v1/audio-analysis/3A4F...    537653.0
# 1001  https://api.spotify.com/v1/audio-analysis/7FpA...    250792.0
# 6041  https://api.spotify.com/v1/audio-analysis/7FpA...    250792.0
# 7098  https://api.spotify.com/v1/audio-analysis/2dPT...    205462.0
#
#      time_signature
# 4194            4.0
# 9234            4.0
# 1001            4.0
# 6041            4.0
# 7098            5.0
#
# [5 rows x 22 columns]

# %%
spotify_df_top1000.describe()
# Out:
#            msPlayed  danceability      energy         key    loudness  \
# count  1.000000e+03     944.00000  944.000000  944.000000  944.000000
# mean   1.012008e+07       0.59894    0.536330    5.266949   -8.536445
# std    1.406547e+07       0.16736    0.219235    3.635096    4.493046
# min    3.360580e+06       0.06310    0.005580    0.000000  -30.777000
# 25%    4.247198e+06       0.50450    0.411000    2.000000   -9.867000
# 50%    5.637525e+06       0.62450    0.541500    5.000000   -7.513500
# 75%    9.443775e+06       0.71900    0.712000    9.000000   -5.609750
# max    1.583671e+08       0.94900    0.996000   11.000000   -1.815000
#
#              mode  speechiness  acousticness  instrumentalness    liveness  \
# count  944.000000   944.000000    944.000000        944.000000  944.000000
# mean     0.614407     0.070644      0.379288          0.102572    0.161386
# std      0.486993     0.069653      0.318428          0.264505    0.109168
# min      0.000000     0.023100      0.000278          0.000000    0.026500
# 25%      0.000000     0.036000      0.079600          0.000000    0.097000
# 50%      1.000000     0.045750      0.316500          0.000008    0.117000
# 75%      1.000000     0.067350      0.665500          0.002500    0.194250
# max      1.000000     0.423000      0.996000          0.989000    0.936000
#
#           valence       tempo   duration_ms  time_signature
# count  944.000000  944.000000  9.440000e+02      944.000000
# mean     0.436073  118.458034  2.226947e+05        3.919492
# std      0.242657   28.331201  1.024851e+05        0.335084
# min      0.022200   47.362000  8.740900e+04        1.000000
# 25%      0.260500   95.083250  1.779380e+05        4.000000
# 50%      0.397000  118.028500  2.038395e+05        4.000000
# 75%      0.624000  136.677000  2.374782e+05        4.000000
# max      0.981000  201.556000  1.847210e+06        5.000000

# %%
fig = plt.figure(figsize=(10,6)); ax = fig.gca()
spotify_df_top1000.hist(bins=30, ax=ax)
plt.suptitle('Spotify top 1000', y=1.03)   
plt.tight_layout()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7024\1760326698.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   spotify_df_top1000.hist(bins=30, ax=ax)

# %% [markdown]
# 🎸 we can see some trends when looking at these distribution for the top 1000 songs: the popular songs seem to center around high danceability and engergy and they tend to be low in speechiness (few words in lyrics)

# %%
g = sns.PairGrid(spotify_df_top1000, x_vars=['danceability', 'energy', 'speechiness', 'acousticness', 'valence'], y_vars=['danceability', 'energy', 'speechiness', 'acousticness', 'valence'])
g = g.map_upper(plt.scatter)
g = g.map_diag(plt.hist, histtype="step", linewidth=2, bins=30)
g = g.map_lower(plt.scatter)
g = g.add_legend()
# Out:
# c:\Users\Admin\anaconda3\envs\CMSE830\Lib\site-packages\seaborn\axisgrid.py:181: UserWarning: The label '_nolegend_' of <matplotlib.patches.Patch object at 0x00000170187EAD90> starts with '_'. It is thus excluded from the legend.
#   figlegend = self._figure.legend(handles, labels, **kwargs)

# %% [markdown]
# 🎸 Take a closer look at the pairplot we can see a somewhat coorelation between danceability vs valence as well as dancebility vs energy

# %% [markdown]
# ### 👉 Dataset 2: Global YouTube Statistics Dataset

# %%
youtube_df = pd.read_csv(r"C:\Users\Admin\OneDrive - Michigan State University\Courses\CMSE 830\HW and Assignment\Dataset\Global YouTube Statistics.csv", encoding_errors='ignore')

# %%
youtube_df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
#
#    Urban_population   Latitude  Longitude
# 0       471031528.0  20.593684  78.962880
# 1       270663028.0  37.090240 -95.712891
# 2       270663028.0  37.090240 -95.712891
# 3       270663028.0  37.090240 -95.712891
# 4       471031528.0  20.593684  78.962880
#
# [5 rows x 28 columns]

# %%
youtube_df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# std     1232.244746        1944.386561                      4.163782e+08
# min        1.000000           1.000000                      1.000000e+00
# 25%       11.000000          27.000000                      2.013750e+07
# 50%       51.000000          65.500000                      6.408500e+07
# 75%      123.000000         139.750000                      1.688265e+08
# max     7741.000000        7741.000000                      6.589000e+09
#
#        lowest_monthly_earnings  highest_monthly_earnings  ...  \
# count               995.000000              9.950000e+02  ...
# mean              36886.148281              5.898078e+05  ...
# std               71858.724092              1.148622e+06  ...
# min                   0.000000              0.000000e+00  ...
# 25%                2700.000000              4.350000e+04  ...
# 50%               13300.000000              2.127000e+05  ...
# 75%               37900.000000              6.068000e+05  ...
# max              850900.000000              1.360000e+07  ...
#
#        highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# count             9.950000e+02                  6.580000e+02    990.000000
# mean              7.081814e+06                  3.490791e+05   2012.630303
# std               1.379704e+07                  6.143554e+05      4.512503
# min               0.000000e+00                  1.000000e+00   1970.000000
# 25%               5.217500e+05                  1.000000e+05   2009.000000
# 50%               2.600000e+06                  2.000000e+05   2013.000000
# 75%               7.300000e+06                  4.000000e+05   2016.000000
# max               1.634000e+08                  8.000000e+06   2022.000000
#
#        created_date  Gross tertiary education enrollment (%)    Population  \
# count    990.000000                               872.000000  8.720000e+02
# mean      15.746465                                63.627752  4.303873e+08
# std        8.777520                                26.106893  4.727947e+08
# min        1.000000                                 7.600000  2.025060e+05
# 25%        8.000000                                36.300000  8.335541e+07
# 50%       16.000000                                68.000000  3.282395e+08
# 75%       23.000000                                88.200000  3.282395e+08
# max       31.000000                               113.100000  1.397715e+09
#
#        Unemployment rate  Urban_population    Latitude   Longitude
# count         872.000000      8.720000e+02  872.000000  872.000000
# mean            9.279278      2.242150e+08   26.632783  -14.128146
# std             4.888354      1.546874e+08   20.560533   84.760809
# min             0.750000      3.558800e+04  -38.416097 -172.104629
# 25%             5.270000      5.590832e+07   20.593684  -95.712891
# 50%             9.365000      2.706630e+08   37.090240  -51.925280
# 75%            14.700000      2.706630e+08   37.090240   78.962880
# max            14.720000      8.429340e+08   61.924110  138.252924
#
# [8 rows x 21 columns]

# %%
fig = plt.figure(figsize=(15,8)); ax = fig.gca()
youtube_df.hist(bins=30, ax=ax)
plt.suptitle('Youtube Global Chart', y=1.03)   
plt.tight_layout()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7024\688137258.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   youtube_df.hist(bins=30, ax=ax)

# %% [markdown]
# ### 👉 Dataset 1: Spotify Song Attributes Dataset

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

spotify_df = pd.read_csv(r"C:\Users\Admin\OneDrive - Michigan State University\Courses\CMSE 830\HW and Assignment\Dataset\Spotify_Song_Attributes.csv")
spotify_df = spotify_df.sort_values("msPlayed", ascending=False)
spotify_df_top1000 = spotify_df[:1000]

# %% [markdown]
# 🎸 There are 10000 records in this dataset but I just want to examine the top 1000 songs based on the total ms that it is played (`"msPlayed"` column)

# %%
spotify_df_top1000.head()
# Out:
#                  trackName    artistName   msPlayed                  genre  \
# 4194  Sparkle - movie ver.      RADWIMPS  158367130                  j-pop
# 9234  Sparkle - movie ver.      RADWIMPS  158367130                  j-pop
# 1001                   色香水  Yoh kamiyama  109652914      japanese teen pop
# 6041                   色香水  Yoh kamiyama  109652914      japanese teen pop
# 7098                  Gone    Blake Rose  105798353  australian electropop
#
#       danceability  energy   key  loudness  mode  speechiness  ...  liveness  \
# 4194         0.372   0.426  11.0    -8.421   1.0       0.0339  ...     0.109
# 9234         0.372   0.426  11.0    -8.421   1.0       0.0339  ...     0.109
# 1001         0.613   0.857   7.0    -5.272   1.0       0.0271  ...     0.256
# 6041         0.613   0.857   7.0    -5.272   1.0       0.0271  ...     0.256
# 7098         0.317   0.545  11.0    -6.439   0.0       0.0468  ...     0.116
#
#       valence    tempo            type                      id  \
# 4194    0.287  123.993  audio_features  3A4FRzgve9BjfKbvVXRIFO
# 9234    0.287  123.993  audio_features  3A4FRzgve9BjfKbvVXRIFO
# 1001    0.698  147.974  audio_features  7FpABRyv5TaZz0llkhjPgc
# 6041    0.698  147.974  audio_features  7FpABRyv5TaZz0llkhjPgc
# 7098    0.140  139.014  audio_features  2dPT9UxyHm71quNyj3C4YE
#
#                                        uri  \
# 4194  spotify:track:3A4FRzgve9BjfKbvVXRIFO
# 9234  spotify:track:3A4FRzgve9BjfKbvVXRIFO
# 1001  spotify:track:7FpABRyv5TaZz0llkhjPgc
# 6041  spotify:track:7FpABRyv5TaZz0llkhjPgc
# 7098  spotify:track:2dPT9UxyHm71quNyj3C4YE
#
#                                              track_href  \
# 4194  https://api.spotify.com/v1/tracks/3A4FRzgve9Bj...
# 9234  https://api.spotify.com/v1/tracks/3A4FRzgve9Bj...
# 1001  https://api.spotify.com/v1/tracks/7FpABRyv5TaZ...
# 6041  https://api.spotify.com/v1/tracks/7FpABRyv5TaZ...
# 7098  https://api.spotify.com/v1/tracks/2dPT9UxyHm71...
#
#                                            analysis_url duration_ms  \
# 4194  https://api.spotify.com/v1/audio-analysis/3A4F...    537653.0
# 9234  https://api.spotify.com/v1/audio-analysis/3A4F...    537653.0
# 1001  https://api.spotify.com/v1/audio-analysis/7FpA...    250792.0
# 6041  https://api.spotify.com/v1/audio-analysis/7FpA...    250792.0
# 7098  https://api.spotify.com/v1/audio-analysis/2dPT...    205462.0
#
#      time_signature
# 4194            4.0
# 9234            4.0
# 1001            4.0
# 6041            4.0
# 7098            5.0
#
# [5 rows x 22 columns]

# %%
spotify_df_top1000.describe()
# Out:
#            msPlayed  danceability      energy         key    loudness  \
# count  1.000000e+03     944.00000  944.000000  944.000000  944.000000
# mean   1.012008e+07       0.59894    0.536330    5.266949   -8.536445
# std    1.406547e+07       0.16736    0.219235    3.635096    4.493046
# min    3.360580e+06       0.06310    0.005580    0.000000  -30.777000
# 25%    4.247198e+06       0.50450    0.411000    2.000000   -9.867000
# 50%    5.637525e+06       0.62450    0.541500    5.000000   -7.513500
# 75%    9.443775e+06       0.71900    0.712000    9.000000   -5.609750
# max    1.583671e+08       0.94900    0.996000   11.000000   -1.815000
#
#              mode  speechiness  acousticness  instrumentalness    liveness  \
# count  944.000000   944.000000    944.000000        944.000000  944.000000
# mean     0.614407     0.070644      0.379288          0.102572    0.161386
# std      0.486993     0.069653      0.318428          0.264505    0.109168
# min      0.000000     0.023100      0.000278          0.000000    0.026500
# 25%      0.000000     0.036000      0.079600          0.000000    0.097000
# 50%      1.000000     0.045750      0.316500          0.000008    0.117000
# 75%      1.000000     0.067350      0.665500          0.002500    0.194250
# max      1.000000     0.423000      0.996000          0.989000    0.936000
#
#           valence       tempo   duration_ms  time_signature
# count  944.000000  944.000000  9.440000e+02      944.000000
# mean     0.436073  118.458034  2.226947e+05        3.919492
# std      0.242657   28.331201  1.024851e+05        0.335084
# min      0.022200   47.362000  8.740900e+04        1.000000
# 25%      0.260500   95.083250  1.779380e+05        4.000000
# 50%      0.397000  118.028500  2.038395e+05        4.000000
# 75%      0.624000  136.677000  2.374782e+05        4.000000
# max      0.981000  201.556000  1.847210e+06        5.000000

# %%
fig = plt.figure(figsize=(10,6)); ax = fig.gca()
spotify_df_top1000.hist(bins=30, ax=ax)
plt.suptitle('Spotify top 1000', y=1.03)   
plt.tight_layout()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7024\1760326698.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   spotify_df_top1000.hist(bins=30, ax=ax)

# %% [markdown]
# 🎸 we can see some trends when looking at these distribution for the top 1000 songs: the popular songs seem to center around high danceability and engergy and they tend to be low in speechiness (few words in lyrics)

# %%
g = sns.PairGrid(spotify_df_top1000, x_vars=['danceability', 'energy', 'speechiness', 'acousticness', 'valence'], y_vars=['danceability', 'energy', 'speechiness', 'acousticness', 'valence'])
g = g.map_upper(plt.scatter)
g = g.map_diag(plt.hist, histtype="step", linewidth=2, bins=30)
g = g.map_lower(plt.scatter)
g = g.add_legend()
# Out:
# c:\Users\Admin\anaconda3\envs\CMSE830\Lib\site-packages\seaborn\axisgrid.py:181: UserWarning: The label '_nolegend_' of <matplotlib.patches.Patch object at 0x000001701C178D50> starts with '_'. It is thus excluded from the legend.
#   figlegend = self._figure.legend(handles, labels, **kwargs)

# %% [markdown]
# 🎸 Take a closer look at the pairplot we can see a somewhat coorelation between danceability vs valence as well as dancebility vs energy

# %% [markdown]
# ### 👉 Dataset 2: Global YouTube Statistics Dataset

# %%
youtube_df = pd.read_csv(r"C:\Users\Admin\OneDrive - Michigan State University\Courses\CMSE 830\HW and Assignment\Dataset\Global YouTube Statistics.csv", encoding_errors='ignore')

# %%
youtube_df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
#
#    Urban_population   Latitude  Longitude
# 0       471031528.0  20.593684  78.962880
# 1       270663028.0  37.090240 -95.712891
# 2       270663028.0  37.090240 -95.712891
# 3       270663028.0  37.090240 -95.712891
# 4       471031528.0  20.593684  78.962880
#
# [5 rows x 28 columns]

# %%
youtube_df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# std     1232.244746        1944.386561                      4.163782e+08
# min        1.000000           1.000000                      1.000000e+00
# 25%       11.000000          27.000000                      2.013750e+07
# 50%       51.000000          65.500000                      6.408500e+07
# 75%      123.000000         139.750000                      1.688265e+08
# max     7741.000000        7741.000000                      6.589000e+09
#
#        lowest_monthly_earnings  highest_monthly_earnings  ...  \
# count               995.000000              9.950000e+02  ...
# mean              36886.148281              5.898078e+05  ...
# std               71858.724092              1.148622e+06  ...
# min                   0.000000              0.000000e+00  ...
# 25%                2700.000000              4.350000e+04  ...
# 50%               13300.000000              2.127000e+05  ...
# 75%               37900.000000              6.068000e+05  ...
# max              850900.000000              1.360000e+07  ...
#
#        highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# count             9.950000e+02                  6.580000e+02    990.000000
# mean              7.081814e+06                  3.490791e+05   2012.630303
# std               1.379704e+07                  6.143554e+05      4.512503
# min               0.000000e+00                  1.000000e+00   1970.000000
# 25%               5.217500e+05                  1.000000e+05   2009.000000
# 50%               2.600000e+06                  2.000000e+05   2013.000000
# 75%               7.300000e+06                  4.000000e+05   2016.000000
# max               1.634000e+08                  8.000000e+06   2022.000000
#
#        created_date  Gross tertiary education enrollment (%)    Population  \
# count    990.000000                               872.000000  8.720000e+02
# mean      15.746465                                63.627752  4.303873e+08
# std        8.777520                                26.106893  4.727947e+08
# min        1.000000                                 7.600000  2.025060e+05
# 25%        8.000000                                36.300000  8.335541e+07
# 50%       16.000000                                68.000000  3.282395e+08
# 75%       23.000000                                88.200000  3.282395e+08
# max       31.000000                               113.100000  1.397715e+09
#
#        Unemployment rate  Urban_population    Latitude   Longitude
# count         872.000000      8.720000e+02  872.000000  872.000000
# mean            9.279278      2.242150e+08   26.632783  -14.128146
# std             4.888354      1.546874e+08   20.560533   84.760809
# min             0.750000      3.558800e+04  -38.416097 -172.104629
# 25%             5.270000      5.590832e+07   20.593684  -95.712891
# 50%             9.365000      2.706630e+08   37.090240  -51.925280
# 75%            14.700000      2.706630e+08   37.090240   78.962880
# max            14.720000      8.429340e+08   61.924110  138.252924
#
# [8 rows x 21 columns]

# %%
fig = plt.figure(figsize=(15,10)); ax = fig.gca()
youtube_df.hist(bins=30, ax=ax)
plt.suptitle('Spotify top 1000', y=1.03)   
plt.tight_layout()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7024\2310496947.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   youtube_df.hist(bins=30, ax=ax)

# %% [markdown]
# 📺It's hard to see the apparent trend looking at only the histograms for this dataset since the data seem to focus around an area with some outliers

# %%
sns.histplot(data=youtube_df[:100], hue="channel_type", x="subscribers", element="step")
# Out:
# <Axes: xlabel='subscribers', ylabel='Count'>

# %%
sns.displot(data=youtube_df[:100], x="video views", hue="Country", kind="kde")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7024\2642166422.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(data=youtube_df[:100], x="video views", hue="Country", kind="kde")

# %% [markdown]
# 📺continue to examine the top 100 subsbribed channels but look at the view count distribution by countries, we can see that India channels gain the most view followed by the US.

# %%
g = sns.PairGrid(youtube_df[:100], x_vars=['subscribers', 'video views', 'uploads', 'highest_yearly_earnings'], 
                 y_vars=['subscribers', 'video views', 'uploads', 'highest_yearly_earnings'])
g = g.map_upper(plt.scatter)
g = g.map_diag(plt.hist, histtype="step", linewidth=2, bins=30)
g = g.map_lower(plt.scatter)
g = g.add_legend()
# Out:
# c:\Users\Admin\anaconda3\envs\CMSE830\Lib\site-packages\seaborn\axisgrid.py:181: UserWarning: The label '_nolegend_' of <matplotlib.patches.Patch object at 0x0000017017817810> starts with '_'. It is thus excluded from the legend.
#   figlegend = self._figure.legend(handles, labels, **kwargs)

# %% [markdown]
# 📺 we can see a correlation between subscirber and view count but huge number of uploads doesn't necessarily ensure high subscriber and view count

# %% [markdown]
# ### 👉 Dataset 3: Vietnam 2021 High School Graduation Exam Marks

# %%
hsg_exam_df = pd.read_csv(r"C:\Users\Admin\OneDrive - Michigan State University\Courses\CMSE 830\HW and Assignment\Dataset\2021.csv", encoding_errors='ignore').dropna(how='all', axis='columns')
hsg_exam_df = hsg_exam_df.drop(hsg_exam_df.columns[hsg_exam_df.columns.str.contains('Unnamed', case=False)], axis=1)

# %%
hsg_exam_df.head()
# Out:
#         id  year  mathematics_score  literature_score  physics_score  \
# 0  1000046  2022                8.0              6.25           7.25
# 1  1000031  2022                7.0              7.75            NaN
# 2  1000012  2022                6.4              7.50            NaN
# 3  1000087  2022                8.4              8.00            NaN
# 4  1000071  2022                7.6              8.25           6.25
#
#    chemistry_score  biology_score  foreign_language_score  \
# 0              5.5           4.75                     4.6
# 1              NaN            NaN                     8.8
# 2              NaN            NaN                     NaN
# 3              NaN            NaN                     9.4
# 4              5.0           3.25                     6.6
#
#   foreign_language_type  english_score  history_score  geography_score  \
# 0                    N1            4.6            NaN              NaN
# 1                    N1            8.8           6.25              5.0
# 2                   NaN            NaN           4.75              5.0
# 3                    N1            9.4           6.75              6.5
# 4                    N1            6.6            NaN              NaN
#
#    civic_education_score  chinese_score  japanese_score  korean_score  \
# 0                    NaN            NaN             NaN           NaN
# 1                   9.00            NaN             NaN           NaN
# 2                   8.00            NaN             NaN           NaN
# 3                   8.25            NaN             NaN           NaN
# 4                    NaN            NaN             NaN           NaN
#
#    french_score  german_score  russian_score
# 0           NaN           NaN            NaN
# 1           NaN           NaN            NaN
# 2           NaN           NaN            NaN
# 3           NaN           NaN            NaN
# 4           NaN           NaN            NaN

# %%
hsg_exam_df.describe()
# Out:
#                  id      year  mathematics_score  literature_score  \
# count  9.953810e+05  995381.0      982670.000000     981351.000000
# mean   2.759687e+07    2022.0           6.466307          6.507771
# std    1.917116e+07       0.0           1.675402          1.379598
# min    1.000001e+06    2022.0           0.000000          0.000000
# 25%    1.000216e+07    2022.0           5.400000          5.580000
# 50%    2.801888e+07    2022.0           6.800000          6.500000
# 75%    4.400583e+07    2022.0           7.800000          7.500000
# max    6.400659e+07    2022.0          10.000000         10.000000
#
#        physics_score  chemistry_score  biology_score  foreign_language_score  \
# count  325510.000000    327353.000000  322185.000000           870571.000000
# mean        6.723776         6.703872       5.019119                5.157718
# std         1.441914         1.600390       1.448270                1.949552
# min         0.000000         0.000000       0.000000                0.000000
# 25%         5.750000         5.500000       4.000000                3.600000
# 50%         7.000000         7.000000       4.750000                4.800000
# 75%         7.750000         8.000000       6.000000                6.600000
# max        10.000000        10.000000      10.000000               10.000000
#
#        english_score  history_score  geography_score  civic_education_score  \
# count  866151.000000  659617.000000    657377.000000          554316.000000
# mean        5.146637       6.343983         6.677960               8.033279
# std         1.942451       1.612875         1.214998               1.067257
# min         0.000000       0.000000         0.000000               0.000000
# 25%         3.600000       5.250000         5.750000               7.500000
# 50%         4.800000       6.500000         6.750000               8.250000
# 75%         6.600000       7.500000         7.500000               8.750000
# max        10.000000      10.000000        10.000000              10.000000
#
#        chinese_score  japanese_score  korean_score  french_score  \
# count    2467.000000      819.000000    286.000000    698.000000
# mean        7.480422        7.021001      6.168531      7.527507
# std         1.996075        2.306926      1.883555      2.216118
# min         0.000000        1.600000      2.000000      2.000000
# 25%         6.200000        5.000000      4.600000      5.800000
# 50%         8.000000        7.600000      6.000000      8.400000
# 75%         9.200000        9.000000      7.600000      9.400000
# max        10.000000       10.000000     10.000000     10.000000
#
#        german_score  russian_score
# count     80.000000      70.000000
# mean       6.867500       8.888571
# std        1.902415       1.506175
# min        2.800000       3.000000
# 25%        5.600000       8.500000
# 50%        7.200000       9.400000
# 75%        8.400000       9.800000
# max        9.600000      10.000000

# %%
fig = plt.figure(figsize=(15,12)); ax = fig.gca()
hsg_exam_df.hist(bins=30, ax=ax)
plt.suptitle('Spotify top 1000', y=1.03)   
plt.tight_layout()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7024\4044908696.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   hsg_exam_df.hist(bins=30, ax=ax)

# %% [markdown]
# 📝 Here we can see the score distribution over all subjects in the graduation exam for vietnamese high school student in 2021. We can see the the score is skewwed for most of the subject. For STEM subjects, the scores center around 6-8. English score and foreign language score is basically the same distribution since the number of students taking english exam is remarkably larger than all the other languages test takers combine. Civic education score is generally high

# %%
#sns.displot(data=hsg_exam_df, x="mathematics_score", y="physics_score", kind="kde")

# %%
g = sns.PairGrid(hsg_exam_df[:100], x_vars=['mathematics_score', 'literature_score', 'english_score', 'physics_score', 'chemistry_score'], 
                 y_vars=['mathematics_score', 'literature_score', 'english_score', 'physics_score', 'chemistry_score'])
g = g.map_upper(plt.scatter)
g = g.map_diag(plt.hist, histtype="step", linewidth=2, bins=30)
g = g.map_lower(plt.scatter)
g = g.add_legend()
# Out:
# c:\Users\Admin\anaconda3\envs\CMSE830\Lib\site-packages\seaborn\axisgrid.py:181: UserWarning: The label '_nolegend_' of <matplotlib.patches.Patch object at 0x000001701C586F90> starts with '_'. It is thus excluded from the legend.
#   figlegend = self._figure.legend(handles, labels, **kwargs)

# %% [markdown]
# 📝 Interestingly, there is decent correlation between math vs literature and math vs english score, students perform well in the math test tend to have a good english and literature score too.

# %% [markdown]
# ____
# ## Pandas Practice
#
# ✍🏻  (10pts) From the standard penguins dataset, answer this question: what percentage of female penguins from Dream have a body mass greater than $4000$ grams? (Use only Pandas attributes and methods. Show your code as well as your answer.)
#
# [Hint.](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)

# %%
import pandas as pd
import seaborn as sns

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
female_dream = penguins_df.loc[(penguins_df['sex'] == "Female") & (penguins_df['island'] == "Dream")]
penguins_gt_4000 = female_dream[['sex', 'island', 'body_mass_g']].groupby(['sex', 'island'], dropna = True).apply(lambda x: x > 4000)
print(penguins_gt_4000)

count_penguins_gt_4000 = penguins_gt_4000.value_counts()
print(f"{count_penguins_gt_4000[True]} is the number of > 4000g female penguins from Dream out of {penguins_gt_4000.shape[0]} female penguins from Dream")
prob = count_penguins_gt_4000[True]/penguins_gt_4000.shape[0]
print(f"The percentage of female penguins from Dream have a body mass greater than 4000 grams is: {prob*100}%")
# Out:
#                    body_mass_g
# sex    island
# Female Dream  30         False
#               32         False
#               34         False
#               37         False
#               38         False
# ...                        ...
#               211        False
#               213        False
#               214        False
#               216        False
#               219        False
#
# [61 rows x 1 columns]
# 1 is the number of > 4000g female penguins from Dream out of 61 female penguins from Dream
# The percentage of female penguins from Dream have a body mass greater than 4000 grams is: 1.639344262295082%

# %%
dream = penguins_df.loc[(penguins_df['island'] == "Dream")]
dream[['sex', 'island', 'body_mass_g']].groupby(['sex', 'island'], dropna = True).apply(lambda x: x > 4000).value_counts()
# Out:
# body_mass_g
# False          95
# True           28
# Name: count, dtype: int64

# %% [markdown]
# 🐧Only 1 out of 61 female penguins from Dream have a body mass greater than 4000 grams. The percentage of female penguins from Dream have a body mass greater than 4000 grams is 1.64%

# %% [markdown]
# ____
# ## Python Practice
#
# ✍🏻 (5 pts) Run each of these codes and explain what how keywords work in Python functions.

# %%
def who_I_am(name, class_number, department):
  print(f"Hello. My name is {name} and I am in {department} {class_number} this semester.")

def who_I_am_kw(name, class_number=830, department="CMSE"):
  print(f"Hello. My name is {name} and I am in {department} {class_number} this semester.")

# %% [markdown]
# 👉 the first function `who_I_am` takes 3 arguments `name`, `class_number`, and `department`, these 3 arguments are positional (the position of the inputed arguements when the function is called decide the value of the arguments variable)
#
# 👉 the first function `who_I_am_kw` takes 1 positional argument: `name` and 2 keyword arguments:`class_number`, and `department`, the 2 keyword arguments have default value defined (if user doesnt put any value for these keyword arguments, they will take the default values)

# %%
who_I_am("John", 830, "CMSE")
# Out:
# Hello. My name is John and I am in CMSE 830 this semester.

# %% [markdown]
# 👉 arguments values in this case:
# * `name = "John"`
# * `class_number = 830`
# * `departmen = "CMSE"`

# %%
who_I_am(830, "CMSE", "John")
# Out:
# Hello. My name is 830 and I am in John CMSE this semester.

# %% [markdown]
# 👉 arguments values in this case:
# * `name = 830`
# * `class_number = "CMSE"`
# * `departmen = "John"`
#
# 👉 when we don't assign the value explicitly (with `<argument_name> = <value>`) for the positional arguments, **position matters!**

# %%
who_I_am(name = "John", class_number = 830, department = "CMSE")
# Out:
# Hello. My name is John and I am in CMSE 830 this semester.

# %% [markdown]
# 👉 arguments values in this case:
# * `name = "John"`
# * `class_number = 830`
# * `departmen = "CMSE"`

# %%
who_I_am(department = "CMSE", class_number = 830, name = "John")
# Out:
# Hello. My name is John and I am in CMSE 830 this semester.

# %% [markdown]
# 👉 arguments values in this case:
# * `name = "John"`
# * `class_number = 830`
# * `departmen = "CMSE"`
#
# 👉 when we assign the value explicitly (with `<argument_name> = <value>`) for the positional arguments position doesn't matter now. The function know which values go to which arguement

# %%
who_I_am_kw("Jack")
# Out:
# Hello. My name is Jack and I am in CMSE 830 this semester.

# %% [markdown]
# 👉 arguments values in this case:
# * `name = "Jack"`
# * `class_number = 830` (default)
# * `departmen = "CMSE"` (default)
#
# 👉 Since only the positional argument is inputed, the other 2 keyword arguments use their default values

# %%
who_I_am_kw("Jack", class_number = 123)
# Out:
# Hello. My name is Jack and I am in CMSE 123 this semester.

# %% [markdown]
# 👉 arguments values in this case:
# * `name = "Jack"`
# * `class_number = 123`
# * `departmen = "CMSE"` (default)
#
# 👉 Now `class_number` is inputted, the default value is overriden by the new value `123`

# %%
who_I_am_kw(class_number = 123, "Jack")
# Out:
#   Cell In[4], line 1
#     who_I_am_kw(class_number = 123, "Jack")
#                                           ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# 👉 Turn out if we use both positional and keyword argument and decide not to explicitly assign values for positional arguments, they have to be called out before any keyword arguments assignment

# %% [markdown]
# ____
# ## PEP-8
#
# ✍🏻 (5 pts) Which of these follows the [PEP-8 standard](https://peps.python.org/pep-0008/)?
#
# * `if x == 4 : print(x , y) ; x , y = y , x`
# * `if x == 4: print(x, y); x, y = y, x`
# * neither of these

# %% [markdown]
# 👉 the second option follows the `PEP-8` standard:
# * `if x == 4: print(x, y); x, y = y, x`

# %% [markdown]
# ____
# ## EDA: Seaborn and Correlations
#
# ✍🏻  (10pts) Read in the mpg dataset and perform EDA on it. Specifically:
# * get the basic statistics from the df,
# * make a `displot` of horsepower versus mpg, including a rug plot and with a kde,
# * make a Seaborn `heatmap` of the correlations using Pandas' `.corr`, with annotations and your choice of colormap,
# * make a `regplot` ([or, `lmplot`](https://seaborn.pydata.org/tutorial/regression.html)) of horsepower versus mpg using the lowess smoother; choose good colors,
# * design a `FacetGrid` of your choice.
#
# After each plot, open a markdown cell and give one sentence of what the plot tells you. That is, as a data scientist, what did this form of EDA reveal about the data? (If it didn't reveal anything to you, that is also an important possible answer.)

# %%
mpg_df = sns.load_dataset(name='mpg')

# %%
mpg_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg_df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
sns.displot(data=mpg_df, x="horsepower", y="mpg", rug=True, kind="kde")

# %% [markdown]
# 📊 The data centers around 20-30 mpg and 50-100 horsepower

# %%
mpg_corr = mpg_df.corr(numeric_only=True)
sns.heatmap(mpg_corr, annot=True, cmap='ocean')
# Out:
# <Axes: >

# %% [markdown]
# 📊 There is a strong positive correlation across cylinder, displacement, horsepower and weight

# %%
sns.regplot(x="horsepower", y="mpg", data=mpg_df)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %% [markdown]
# 📊 horsepower and mpg fit really well into a regression model

# %%
g = sns.FacetGrid(mpg_df, col="origin")
g.map_dataframe(sns.scatterplot, x="mpg", y="horsepower", hue="model_year")
g.add_legend()

# %% [markdown]
# 📊USA has the largest number of model and are the only producer of heavy horsepower > 150 model. Newer models perform better in terms of mpg
